# %%
from simulation import *
from aesthetics import *
from models import *
from data import *
from analysis import *

import glob
import os as os
import re as re
import pandas as pd

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
mpl.rc('text', usetex=True)

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi1ASN138'
this.cSubstrate = 1e-3
this.simulate()
this.plot_energy()

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi1MET174'
this.cSubstrate = 1e-3
this.simulate()
this.plot_energy()

# %% [markdown]
# Okay, let's reverse and average these two and see what it looks like.

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi1ASN138'
this.cSubstrate = 1e-3
this.simulate()

data = this.unbound_population[1:]
reversed_data = data[::-1]
unbound_averaged = (data + reversed_data) / 2.
# unbound_averaged = np.concatenate(([60], unbound_averaged))

data = this.bound_population[1:]
reversed_data = data[::-1]
bound_averaged = (data + reversed_data) / 2.
# bound_averaged = np.concatenate(([60], bound_averaged))

this = simulation(data_source='manual')
this.cSubstrate = 1e-3
this.unbound_population = unbound_averaged
this.bound_population = bound_averaged
this.C_intersurface = +1.00e+06 
this.offset_factor = 5.7 
this.catalytic_rate = +3.12e+02
this.simulate()
this.plot_input()
this.plot_energy()
this.plot_flux()
# Out:
# Using manual parameters, specify C, offset, and catalytic rate.
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         -1.29e-05  cycle second**-1
# Peak intrasurface flux    +5.59e+01  cycle second**-1
# Intersurface flux         +3.77e-05  cycle second**-1

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi1MET174'
this.cSubstrate = 1e-3
this.simulate()

data = this.unbound_population[1:]
reversed_data = data[::-1]
unbound_averaged = (data + reversed_data) / 2.
# unbound_averaged = np.concatenate(([60], unbound_averaged))

data = this.bound_population[1:]
reversed_data = data[::-1]
bound_averaged = (data + reversed_data) / 2.
# bound_averaged = np.concatenate(([60], bound_averaged))

this = simulation(data_source='manual')
this.cSubstrate = 1e-3
this.unbound_population = unbound_averaged
this.bound_population = bound_averaged
this.C_intersurface = +1.00e+06 
this.offset_factor = 5.7 
this.catalytic_rate = +3.12e+02
this.simulate()
this.plot_input()
this.plot_energy()
this.plot_flux()
# Out:
# Using manual parameters, specify C, offset, and catalytic rate.
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         -1.02e-05  cycle second**-1
# Peak intrasurface flux    +4.78e+01  cycle second**-1
# Intersurface flux         +2.97e-05  cycle second**-1
