# %% [markdown]
# # Diffusion of a population spike

# %%
from simulation import *
from aesthetics import *
from models import *
from data import *

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
mpl.rc('text', usetex=True)

import pandas as pd
import scipy as sc
import os as os
import re as re

# %%
name = 'psiSER311'
this = simulation(data_source = 'manual')
this.unbound_population = np.array([1] * 60)
this.bound_population = np.array([1] * 60)
this.C_intersurface = 0.24 * 10**6
this.offset_factor = 0
this.catalytic_rate = 0
this.iterations = 50
this.simulate()
# Out:
# Using manual parameters, specify C, offset, and catalytic rate.
# Running iterative method with 50 iterations
# MSD = 144.0
# MSD = 150.00006220799997
# MSD = 156.00012441598506
# MSD = 162.00018662395513
# MSD = 168.00024883191026
# MSD = 174.00031103985037
# MSD = 180.0003732477756
# MSD = 186.00043545568585
# MSD = 192.0004976635811
# MSD = 198.00055987146143
# MSD = 204.00062207932677
# MSD = 210.0006842871772
# MSD = 216.00074649501263
# MSD = 222.0008087028331
# MSD = 228.00087091063864
# MSD = 234.0009331184292
# MSD = 240.0009953262048
# MSD = 246.00105753396542
# MSD = 252.0011197417111
# MSD = 258.0011819494419
# MSD = 264.0012441571576
# MSD = 270.0013063648584
# MSD = 276.0013685725442
# MSD = 282.0014307802151
# MSD = 288.001492987871
# MSD = 294.00155519551197
# MSD = 300.00161740313797
# MSD = 306.00167961074897
# MSD = 312.00174181834507
# MSD = 318.0018040259263
# MSD = 324.0018662334924
# MSD = 330.0019284410436
# MSD = 336.00199064857986
# MSD = 342.0020528561011
# ...
