# %%
from simulation import *
from aesthetics import *
from models import *
from data import *
from analysis import *

import glob
import os as os
import re as re
import pandas as pd

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
mpl.rc('text', usetex=True)

# %%
df = pd.read_pickle('adk-concentration-scan.pickle')

# %%
df[(df['Directional flux'] < 1) & (df['Directional flux'] > -1) & (np.round(df['Concentration'], 1) == -3.0)].head(5)
# Out:
#        Concentration  Directional flux  Driven flux        File  \
# 27090           -3.0         -0.144208    10.573240   chi1ALA11
# 27091           -3.0         -0.007508     3.124329  chi1ALA127
# 27092           -3.0         -0.032975     7.072458   chi1ALA17
# 27093           -3.0          0.014157     4.480657  chi1ALA176
# 27094           -3.0          0.013930     1.639636  chi1ALA186
#
#        Intersurface flux  Max load  Max power ResID
# 27090           3.059189       0.0        0.0    11
# 27091           1.412363       0.0        0.0   127
# 27092           2.718294       0.0        0.0    17
# 27093           1.624334       0.0        0.0   176
# 27094           0.580522       0.0        0.0   186

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi1ALA17'
this.cSubstrate = 1e-3
this.simulate()
this.plot_flux()
# Out:
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         -3.30e-02  cycle second**-1
# Peak intrasurface flux    +7.07e+00  cycle second**-1
# Intersurface flux         +3.93e-05  cycle second**-1

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi1ALA176'
this.cSubstrate = 1e-3
this.simulate()
this.plot_flux()
# Out:
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         +1.41e-02  cycle second**-1
# Peak intrasurface flux    +4.48e+00  cycle second**-1
# Intersurface flux         +3.75e-06  cycle second**-1

# %% [markdown]
# Okay, now let's look for angle where there is a resonable amount of directional flux and see if there are elements of driven flux too.

# %%
df[(df['Directional flux'] > 1) & (df['Directional flux'] < 2) & (np.round(df['Concentration'], 1) == -3.0)].head(5)
# Out:
#        Concentration  Directional flux  Driven flux        File  \
# 27123           -3.0          1.769209   118.517555  chi1ASN138
# 27137           -3.0          1.124429    87.262944   chi1ASP51
# 27158           -3.0          1.376314    18.693963  chi1GLU162
# 27222           -3.0          1.890976   128.269523  chi1MET174
# 27252           -3.0          1.187340    31.356846  chi1THR175
#
#        Intersurface flux  Max load  Max power ResID
# 27123          34.547893   0.00006   0.000054   138
# 27137          22.310804   0.00001   0.000006    51
# 27158           4.125215   0.00000   0.000000   162
# 27222          28.454176   0.00001   0.000011   174
# 27252          18.910606   0.02799   0.017107   175

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi1ASN138'
this.cSubstrate = 1e-3
this.simulate()
this.plot_flux()
# Out:
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         +1.77e+00  cycle second**-1
# Peak intrasurface flux    +1.19e+02  cycle second**-1
# Intersurface flux         +1.70e-05  cycle second**-1

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi1MET174'
this.cSubstrate = 1e-3
this.simulate()
this.plot_flux()
# Out:
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         +1.89e+00  cycle second**-1
# Peak intrasurface flux    +1.28e+02  cycle second**-1
# Intersurface flux         +7.70e-06  cycle second**-1
